# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('IncrementalPipline').getOrCreate()

# %%
new_customers = spark.read.csv('/Volumes/workspace/default/retail_data/customers.csv',
    inferSchema=True)

# %%
customer_columns = [
    "customer_id",
    "customer_fname",
    "customer_lname",
    "customer_email",
    "customer_password",
    "customer_street",
    "customer_city",
    "customer_state",
    "customer_zipcode"
]

new_customers = new_customers.toDF(*customer_columns)

# %%
new_customers.write.format("delta") \
.mode("overwrite") \
.saveAsTable("retail_silver.customers_stg")

# %%
# %sql 
MERGE INTO retail_silver.customers AS target
USING retail_silver.customers_stg AS source
ON target.customer_id = source.customer_id
WHEN MATCHED THEN
UPDATE SET *
WHEN NOT MATCHED THEN
INSERT *
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>12435</td><td>12435</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
new_orders = spark.read.csv('/Volumes/workspace/default/retail_data/orders.csv',
    inferSchema=True)

# %%
orders_columns = [
    "order_id",
    "order_date",
    "order_customer_id",
    "order_status"
]

new_orders = new_orders.toDF(*orders_columns)

# %%
new_orders.write.format("delta") \
.mode("overwrite") \
.saveAsTable("retail_silver.orders_stg")

# %%
# %sql
MERGE INTO retail_silver.orders AS target
USING retail_silver.orders_stg AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
UPDATE SET *
WHEN NOT MATCHED THEN 
INSERT *
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>68883</td><td>68883</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
new_products = spark.read.csv('/Volumes/workspace/default/retail_data/products.csv',inferSchema=True)

# %%
products_columns =[
    "product_id",
    "product_cateogry_id",
    "product_name",
    "product_description",
    "product_price",
    "product_image"
] 

new_products = new_products.toDF(*products_columns)

# %%
new_products.write.format('delta') \
.mode('overwrite') \
.saveAsTable('retail_silver.products_stg')

# %%
# %sql
MERGE INTO retail_silver.products AS target
USING retail_silver.products_stg AS source
ON target.product_id = source.product_id
WHEN MATCHED THEN
UPDATE SET *
WHEN NOT MATCHED THEN
INSERT *
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1345</td><td>1345</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
new_order_items = spark.read.csv('/Volumes/workspace/default/retail_data/order_item.csv',inferSchema=True)

# %%
order_items_columns = [
    "order_item_id",
    "order_item_order_id",
    "order_item_product_id",
    "order_item_quantity",
    "order_item_subtotal",
    "order_item_product_price"
]

new_order_items = new_order_items.toDF(*order_items_columns)

# %%
new_order_items.write.format('delta')\
    .mode('overwrite')\
    .saveAsTable('retail_silver.order_items_stg')

# %%
# %sql MERGE INTO retail_silver.order_items AS target
USING retail_silver.order_items_stg AS source
ON target.order_item_id = source.order_item_id
WHEN MATCHED THEN 
UPDATE SET *
WHEN NOT MATCHED THEN 
INSERT *
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>172198</td><td>172198</td><td>0</td><td>0</td></tr></tbody></table></div>
