# %% [markdown]
# # Pipeline Orchestration
#
# This notebook explains the orchestration flow used
# to automate the Retail Sales Analytics ETL pipeline
# using Databricks Workflows.

# %% [markdown]
# # Workflow Execution Sequence
#
# 01_data_ingestion
# ↓
#
# 02_data_cleaning_silver_layer
# ↓
#
# 04_incremental_load_pipeline
# ↓
#
# 05_data_quality_checks
# ↓
#
# 06_pipeline_optimization
# ↓
#
# 03_gold_business_analytics
# ↓
#
# Power BI Dashboard

# %% [markdown]
# # Scheduling Strategy
#
# The ETL pipeline can be scheduled using Databricks Jobs
# to execute automatically at defined intervals such as:
#
# - Daily
# - Hourly
# - Weekly
#
# This enables automated ingestion, transformation,
# validation, and reporting workflows.
